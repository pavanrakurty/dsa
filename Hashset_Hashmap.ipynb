# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanrakurty/dsa/blob/main/Hashset_Hashmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##hash set

##Hash sets are useful for easy lookip O(1)

st = 'aaaaabbbbbccccdddddeeeeeee'

sett = set(st)
print(sett)
# Out:
# {'a', 'd', 'b', 'c', 'e'}

# %%
if 'a' in sett: ##O(1) operation to lookup
  print(True)
# Out:
# True

# %%
## hashmap - dictionary

d = {'greg':1, 'sai':2, 'pavan':3}
print(d)

print(d['greg']) ##O(1)
# Out:
# {'greg': 1, 'sai': 2, 'pavan': 3}
# 1
